# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import pickle
import shelve
import klepto
from gensim import corpora, models
import feather
from collections import defaultdict
import itertools

# %%
poor_data = pd.read_pickle("/Users/Hun/hse_thesis/hse_thesis1.pickle")

# %%
add_data = pd.read_csv("/Users/Hun/hse_thesis/metadata.csv", encoding="CP1251",
                        error_bad_lines=False, warn_bad_lines=False,
                       header=None)
# Out:
# /Users/Hun/Python_env/Python3_env/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
add_data.drop(0, axis=1, inplace=True)

# %%
col_names=["author_id", "wall_id", "post_comment_id", "date", "name", "surname", "sex", "city", "region",
      "country", "posts", "comments", "likes", "reposts", "res_postlikes", "res_comments", "university",
       "freinds", "groups", "followers"]

# %%
len(col_names)
# Out:
# 20

# %%
add_data.columns = col_names
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-108-bb18527797fd> in <module>()
# ----> 1 add_data.columns = col_names
#
# /Users/Hun/Python_env/Python3_env/lib/python3.5/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    2680         try:
#    2681             object.__getattribute__(self, name)
# -> 2682             return object.__setattr__(self, name, value)
#    2683         except AttributeError:
#    2684             pass
#
# pandas/src/properties.pyx in pandas.lib.AxisProperty.__set__ (pandas/lib.c:45018)()
#
# /Users/Hun/Python_env/Python3_env/lib/python3.5/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     423
#     424     def _set_axis(self, axis, labels):
# --> 425         self._data.set_axis(axis, labels)
#     426         self._clear_item_cache()
#     427
#
# /Users/Hun/Python_env/Python3_env/lib/python3.5/site-packages/pandas/core/internals.py in set_axis(self, axis, new_labels)
#    2576             raise ValueError('Length mismatch: Expected axis has %d elements, '
#    2577                              'new values have %d elements' %
# -> 2578                              (old_len, new_len))
#    2579
#    2580         self.axes[axis] = new_labels
#
# ValueError: Length mismatch: Expected axis has 15 elements, new values have 20 elements

# %%
add_data["wall_id"] = add_data["wall_id"].apply(lambda text: int(text.split()[-1]))

add_data["post_comment_id_int"] = add_data["post_comment_id"].apply(lambda text: int(text.split()[-1]))
add_data["is_post"] = add_data["post_comment_id"].apply(lambda text: text.split()[0] == "post")
                                                        
poor_data["post_comment_id_int"] = poor_data["post_comment_id"].apply(lambda text: int(text.split()[-1]))
poor_data["is_post"] = poor_data["post_comment_id"].apply(lambda text: text.split()[0] == "post")
                                                        
add_data.drop(["post_comment_id", "date", "name", "surname", "city", "region", "country"], axis=1, inplace=True)
poor_data.drop("post_comment_id", axis=1, inplace=True)

# %%
add_data
# Out:
#          author_id    wall_id sex  posts  comments  likes  res_comments  \
# 0         85978354  112465206   2    1.0       0.0    0.0           0.0
# 1         28098487   28098487   2   12.0       0.0    2.0           0.0
# 2         28098487   28098487   2   12.0       0.0    2.0           0.0
# 3         28098487   28098487   2   12.0       0.0    2.0           0.0
# 4         28098487   28098487   2   12.0       0.0    2.0           0.0
# 5         28098487   28098487   2   12.0       0.0    2.0           0.0
# 6         28098487   28098487   2   12.0       0.0    2.0           0.0
# 7         28098487   28098487   2   12.0       0.0    2.0           0.0
# 8         28098487   28098487   2   12.0       0.0    2.0           0.0
# 9         28098487   28098487   2   12.0       0.0    2.0           0.0
# 10        28098487   28098487   2   12.0       0.0    2.0           0.0
# 11        28098487   28098487   2   12.0       0.0    2.0           0.0
# 12        28098487   28098487   2   12.0       0.0    2.0           0.0
# 13       238477276  238477276   2  179.0       0.0    0.0           0.0
# 14       238477276  238477276   2  179.0       0.0    0.0           0.0
# 22                 6.0           0.0                  3.0    19.0        3.0
# 23                 6.0           0.0                  3.0    19.0        3.0
# 24                 6.0           0.0                  3.0    19.0        3.0
# 25                 6.0           0.0                  3.0    19.0        3.0
# 26                 6.0           0.0                  3.0    19.0        3.0
# 27                 6.0           0.0                  3.0    19.0        3.0
# 28                 6.0           0.0                  3.0    19.0        3.0
# 29                 6.0           0.0                  3.0    19.0        3.0
# ...                ...           ...         ...      ...     ...        ...
# 8166474           48.0           0.0                 58.0    32.0        8.0
# 8166475           48.0           0.0                 58.0    32.0        8.0
# 8166476           48.0           0.0                 58.0    32.0        8.0
# 8166477           48.0           0.0                 58.0    32.0        8.0
# 8166478           48.0           0.0                 58.0    32.0        8.0
# 8166479           48.0           0.0                 58.0    32.0        8.0
# 8166480           48.0           0.0                 58.0    32.0        8.0
# 8166481           48.0           0.0                 58.0    32.0        8.0
# 8166482           48.0           0.0                 58.0    32.0        8.0
# 8166483           48.0           0.0                 58.0    32.0        8.0
# 8166484           48.0           0.0                 58.0    32.0        8.0
# 8166485           48.0           0.0                 58.0    32.0        8.0
# 8166486           48.0           0.0                 58.0    32.0        8.0
# 8166487           48.0           0.0                 58.0    32.0        8.0
# 8166488           48.0           0.0                 58.0    32.0        8.0
# 8166489           48.0           0.0                 58.0    32.0        8.0
# 8166490           48.0           0.0                 58.0    32.0        8.0
# 8166491           48.0           0.0                 58.0    32.0        8.0
# 8166492            0.0           0.0                 56.0    12.0       21.0
# 8166493            0.0           0.0                 56.0    12.0       21.0
# 8166494            0.0           0.0                 56.0    12.0       21.0
# 8166495            1.0           0.0        ЯГТУ      NaN     NaN        NaN
# 8166496            0.0           0.0                 56.0    12.0       21.0
# 8166497            1.0           0.0        ЯГТУ      NaN     NaN        NaN
# 8166498            1.0           0.0        ЯГТУ      NaN     NaN        NaN
# 8166499            1.0           0.0        ЯГТУ      NaN     NaN        NaN
# 8166500            1.0           0.0        ЯГТУ      NaN     NaN        NaN
# 8166501            1.0           0.0        ЯГТУ      NaN     NaN        NaN
# 8166502            0.0           0.0                 56.0    12.0       21.0
# 8166503            0.0           0.0   МИЭП (ЯФ)    150.0    91.0       88.0
#
#          post_comment_id_int is_post
# 0                          1    True
# 1                        249    True
# 2                        246    True
# 3                        245    True
# 4                        244    True
# 5                        243    True
# 6                        241    True
# 7                        240    True
# 8                        239    True
# 9                        237    True
# 10                       236    True
# 11                       182    True
# 12                       117    True
# 13                       196    True
# 14                       195    True
# 15                       194    True
# 16                       193    True
# 17                       192    True
# 18                       191    True
# 19                       190    True
# 20                       188    True
# 21                       187    True
# 22                       186    True
# 23                       185    True
# 24                       184    True
# 25                       183    True
# 26                       182    True
# 27                       181    True
# 28                       180    True
# 29                       179    True
# ...                      ...     ...
# 8166474                   48    True
# 8166475                   47    True
# 8166476                   45    True
# 8166477                   44    True
# 8166478                   43    True
# 8166479                   40    True
# 8166480                   39    True
# 8166481                   38    True
# 8166482                   37    True
# 8166483                   36    True
# 8166484                   35    True
# 8166485                   29    True
# 8166486                   28    True
# 8166487                   26    True
# 8166488                   24    True
# 8166489                   23    True
# 8166490                   22    True
# 8166491                   21    True
# 8166492                  397    True
# 8166493                  343    True
# 8166494                  329    True
# 8166495                  317    True
# 8166496                  314    True
# 8166497                  273    True
# 8166498                  247    True
# 8166499                  116    True
# 8166500                  115    True
# 8166501                  114    True
# 8166502                   43    True
# 8166503                   36    True
#
# [8166504 rows x 15 columns]

# %%
add_data.isnull().sum()
# Out:
# author_id                   0
# wall_id                     0
# sex                    114341
# posts                  114341
# comments               114341
# likes                  114341
# res_comments           114341
# res_postlikes          114341
# res_comments           114341
# university             114341
# freinds                226633
# groups                 226633
# followers              226633
# post_comment_id_int         0
# is_post                     0
# dtype: int64

# %%
add_data.shape
# Out:
# (8166504, 15)

# %%
add_data.drop_duplicates(subset=["wall_id", "post_comment_id_int", "author_id", "is_post"], inplace=True)

# %%
add_data.shape
# Out:
# (8079280, 15)

# %%
data = pd.merge(poor_data, add_data, on=["wall_id", "post_comment_id_int", "author_id", "is_post"], how="left")

# %%
data.head()
# Out:
#                 text  author_id   wall_id                date     name  \
# 0       general lee    49154141  49154141 2012-02-24 11:54:20  Дмитрий
# 1            shelby    49154141  49154141 2012-02-24 11:54:33  Дмитрий
# 2      ford mustang    49154141  49154141 2012-02-25 22:27:35  Дмитрий
# 3        murcielago    49154141  49154141 2012-02-24 11:53:51  Дмитрий
# 4  суровый водитель    49154141  49154141 2012-02-23 16:22:56  Дмитрий
#
#     surname      city                region  text_length  post_comment_id_int  \
# 0  Филиппов  Владимир  Владимирская область            2                 2404
# 1  Филиппов  Владимир  Владимирская область            1                 2405
# 2  Филиппов  Владимир  Владимирская область            2                 2411
# 3  Филиппов  Владимир  Владимирская область            1                 2400
# 4  Филиппов  Владимир  Владимирская область            2                 2392
#
#      ...       posts comments   likes  res_comments  res_postlikes  \
# 0    ...      2133.0      0.0  1352.0           0.0         2670.0
# 1    ...      2133.0      0.0  1352.0           0.0         2670.0
# 2    ...      2133.0      0.0  1352.0           0.0         2670.0
# 3    ...      2133.0      0.0  1352.0           0.0         2670.0
# 4    ...      2133.0      0.0  1352.0           0.0         2670.0
#
#    res_comments  university  freinds groups  followers
# 0           0.0                198.0  106.0      113.0
# 1           0.0                198.0  106.0      113.0
# 2           0.0                198.0  106.0      113.0
# 3           0.0                198.0  106.0      113.0
# 4           0.0                198.0  106.0      113.0
#
# [5 rows x 22 columns]

# %%
poor_data.shape, add_data.shape, data.shape
# Out:
# ((5392586, 11), (8079280, 15), (5392586, 22))

# %%
data.isnull().sum()
# Out:
# text                        0
# author_id                   0
# wall_id                     0
# date                        0
# name                    48759
# surname                 49346
# city                   411426
# region                 421852
# text_length                 0
# post_comment_id_int         0
# is_post                     0
# sex                    184556
# posts                  184556
# comments               184556
# likes                  184556
# res_comments           184556
# res_postlikes          184556
# res_comments           184556
# university             184556
# freinds                263451
# groups                 263451
# followers              263451
# dtype: int64

# %% [markdown]
# Ограничиваем данные постами, написанными позже 20 октября 2010 года и считаем их количество:

# %%
data_good_date = data[data.date >= datetime.date(year=2010,month=10,day=21)]
data_good_date.shape
# Out:
# (5121979, 22)

# %% [markdown]
# Определяем пользователей, у которых 50 и более слов за рассчётный период. Создаём с ними данные

# %%
groupedby_author_sum = data_good_date.groupby("author_id").agg({"text_length": "sum"})
groupedby_author_sum_50 = groupedby_author_sum[groupedby_author_sum["text_length"] >= 50]
authors_50 = groupedby_author_sum_50.index.values
data_authors_50 = data_good_date[data_good_date["author_id"].isin(authors_50)]

# %%
data_authors_50.shape
# Out:
# (4414265, 22)

# %% [markdown]
# Смотрим пользователей по регионам

# %%
data_authors_50["region"].value_counts()
# Out:
# Тюменская область                  202486
# Пензенская область                 139186
# Севастопольский городской совет    127923
# Крым область                       100095
# Дагестан                            98537
# Орловская область                   91166
# Архангельская область               90603
# Коми                                90374
# Ленинградская область               89177
# Московская область                  87213
# Краснодарский край                  83567
# Мордовия                            78327
# Санкт-Петербург                     75861
# Москва                              74280
# Ставропольский край                 72514
# Вологодская область                 72444
# Карелия                             72401
# Псковская область                   71511
# Нижегородская область               71079
# Новосибирская область               70385
# Северная Осетия - Алания            67505
# Воронежская область                 67217
# Татарстан                           64926
# Хакасия                             64754
# Ярославская область                 62077
# Калужская область                   62040
# Липецкая область                    61875
# Саратовская область                 61783
# Костромская область                 61742
# Самарская область                   59295
#                                     ...
# Gouvernorat de Tunis                    1
# Ankara Ili                              1
# Tianjin Municipality                    1
# Pirkanmaa                               1
# Shanxi Province                         1
# Bundesland Tirol                        1
# San Giljan                              1
# Maseru District                         1
# Ошская                                  1
# Arkansas                                1
# Shanghai Municipality                   1
# Jihocesky Kraj                          1
# Bundesland Niederosterreich             1
# Kanton Zurich                           1
# Saint George                            1
# Regione Puglia                          1
# Opstina Bar                             1
# Scotland                                1
# Provincia Granma                        1
# Ниспоренский                            1
# Hainan Province                         1
# Mestna Obcina Celje                     1
# Binh Thu?n                              1
# Estado de Sao Paulo                     1
# Нарынская                               1
# Departement de l' Oueme                 1
# Wojewodztwo Dolnoslaskie                1
# Provincia de Ciego de Avila             1
# Parish of Saint Mary                    1
# Gyeonggi Province                       1
# Name: region, dtype: int64

# %% [markdown]
# Возьмём пользователей с регионами, в которых более 10000 текстов

# %%
valid_regions = data_authors_50["region"].value_counts()[data_authors_50["region"].value_counts() > 10000].axes[0].tolist()
data_authors_50 = data_authors_50[data_authors_50["region"].isin(valid_regions)]
data_authors_50.isnull().sum()
# Out:
# text                        0
# author_id                   0
# wall_id                     0
# date                        0
# name                        0
# surname                     0
# city                        0
# region                      0
# text_length                 0
# post_comment_id_int         0
# is_post                     0
# sex                     84463
# posts                   84463
# comments                84463
# likes                   84463
# res_comments            84463
# res_postlikes           84463
# res_comments            84463
# university              84463
# freinds                150747
# groups                 150747
# followers              150747
# dtype: int64

# %%
data_authors_50.shape
# Out:
# (4163945, 22)

# %% [markdown]
# Авторов, у которых менее 300 слов, сливаем целиком за весь период.

# %%
groupedby_author_sum = data_authors_50.groupby("author_id").agg({"text_length": "sum"})
authors_300 = groupedby_author_sum[groupedby_author_sum["text_length"] <= 300].index.values
data_authors_300 = data_authors_50[data_authors_50["author_id"].isin(authors_300)]
data_authors_300.shape
# Out:
# (346635, 22)

# %%
aggregations = {"text": "sum", "region": "first", "city": "first", "sex": "first", "posts": "sum",
                "comments": "sum", "likes": "sum", "res_postlikes": "sum",
                "freinds": "sum", "groups": "sum", "followers": "sum"}

# если добавить res_comments, вылезает ошибка.

# %%
data_authors_300["res_comments"].mean()
# Out:
# res_comments    5.085521
# res_comments    0.527215
# dtype: float64

# %%
merged_300 = data_authors_300.groupby("author_id").agg(aggregations)

# %%
merged_300
# Out:
#                                                 res_comments             \
#                                                         text    wall_id
# author_id
# 23835                                       придти рыбка vk   110573213
# 47882      машин ваз довольный почесть устраивать устраив...     432243
# 78076      прибывать удача экзамен юный кинуть подношение...   14813366
# 106198     викторий отправлять подарок энергия игра тайна...  175126132
# 107733                         помнить жизнь повторять огнь   104925101
# 133576                благодарность внимательный осторожный      133576
# 180542                                                super   163342675
# 192888     добрый целить близкий девушка красавица форма ...  105405846
# 209827                                            happy amy    15828128
# 210352     мудак подумать хороший версия многий объяснять...     210352
# 279145                                        день рождение    14126318
# 287377                                         vk top cards    76178357
# 325198                        поздравлять целовать обнимать   112218870
# 330299     голуба берет материал важный прохождение квест...  175126132
# 339991     провозглашать давным-давно невинный екатеринбу...    4740965
# 358373     формат вечеринка хороший dj ведущая шоу програ...   71804643
# 370094          март красивый картинка открытка vk fotomimi    20282956
# 380522     здравствовать находить поиск вконтакте жить ме...   44037100
# 401840                         велосипед женский stern maya      401840
# 409409                                     бодрый утро утро      409409
# 423675     желать громкий счастие радость чудо диван воня...    8316129
# 426727     московский фестиваль японский культура oni yor...     426727
# 436111                                   катить ливень лила    16171407
# 456500              простой деталь спасать жизнь сотня дитя   273278360
# 456783                                         vk top cards   135385775
# 509970     именины поздравлять татьяна величать праздник ...   38738544
# 515998     этигэл увидеться суббота февраль asia party de...   65089505
# 516946     олечка здоровье счастие семейный благополучие ...   13383191
# 532494     увидеть застывать суметь сердце невесомый душ ...   30030198
# 577695                                            улыбаться    14229373
# ...                                                      ...        ...
# 314302069                    настя дарить букет забирать vk   269426376
# 314771762  мегатест какать мир аниме хз чито написать рез...  292021717
# 314971310  ян воронович минитест кухня показывать результ...  221550714
# 315015055  вертушка клуб бпан посадка авто трек загорелый...  174747987
# 315240505  лето солнце мор вечеринка утро сидеть играть к...  237732361
# 315584598  помощь золотой осень заходить игра придти золо...  208540168
# 315684420  мегатест пингвин мадагаскар тест помогать похо...  250787004
# 315714232    мегатест какать стихия стихия тест vk megatest   261222906
# 315920586                                      vk top cards   203593150
# 316213865  александр саможенова минитест будущее показыва...  245371508
# 317304138  мегатест хороший проверять хороший тест vk meg...  157946200
# 317445970         мегатест бояться бояться тест vk megatest   215697543
# 317650205  мегатест маг пройти тест маг часть тест vk meg...  274426646
# 317749425  вертушка клуб марьян трек макароны заходить кл...  174747987
# 317862035                 открытка поздравление открытка vk   178141204
# 318746337                          подумать игорёшка правда   214594608
# 319228302  dj даша зажигать клуб pony art magic трек пинк...  258078334
# 316213865      Новосибирск  Новосибирская область           9
# 317304138            Химки     Московская область           7
# 317445970        Киселевск    Кемеровская область           6
# 317650205      Зеленогорск      Красноярский край           9
# 317749425   Ростов-на-Дону     Ростовская область          11
# 317862035        Челябинск    Челябинская область           4
# 318746337       Красноярск      Красноярский край           3
# 319228302         Перлевка    Воронежская область          22
# 319474302        Жигулевск      Самарская область          17
# 319513618            Уктур       Хабаровский край           5
# 319609422           Калуга      Калужская область           3
# 320192054             Тула       Тульская область          26
# 320257199        Ярославль    Ярославская область          13
# 320383218           Брянск       Брянская область           8
# 321477086          Саранск               Мордовия          10
# 321484282     Екатеринбург   Свердловская область           8
# 322263513           Волхов  Ленинградская область           9
# 322306542            Курск        Курская область          12
# 324388472        Субботино    Воронежская область          55
# 324561561             Тула       Тульская область           9
# 326329058           Липецк       Липецкая область           9
#
#                                          ...       text                   \
#           post_comment_id_int is_post    ...    is_post   posts comments
# author_id                                ...
# 23835                     568    True    ...       25.0   625.0     25.0
# 47882                      80    True    ...        3.0    21.0      0.0
# 78076                   10202    True    ...       18.0   630.0    324.0
# 106198                    260    True    ...        8.0    64.0      0.0
# 107733                    556    True    ...       10.0   260.0    120.0
# 133576                    665    True    ...        6.0   630.0     12.0
# 180542                    115    True    ...        7.0    70.0      7.0
# 192888                    764    True    ...        1.0     1.0      0.0
# 209827                  21650    True    ...       19.0     NaN      NaN
# 210352                    826    True    ...        5.0    70.0      0.0
# 279145                    254    True    ...       11.0   363.0     11.0
# 287377                   1052    True    ...       10.0   100.0      0.0
# 325198                   2223    True    ...        7.0    49.0     63.0
# 330299                    269    True    ...       20.0   400.0      0.0
# 339991                    826    True    ...        1.0     1.0      0.0
# 358373                   2019    True    ...        2.0     2.0      0.0
# 370094                    540    True    ...       12.0   156.0     24.0
# 380522                     17    True    ...        1.0     1.0      0.0
# 401840                     17    True    ...        3.0    51.0      0.0
# 409409                    486    True    ...       15.0   330.0      0.0
# 423675                   1074    True    ...        5.0    55.0     30.0
# 426727                    192    True    ...        7.0   161.0     70.0
# 436111                   5734    True    ...       34.0  1904.0   1326.0
# 456500                     29    True    ...       17.0     NaN      NaN
# 456783                    246    True    ...       22.0   638.0      0.0
# 509970                    235    True    ...        8.0    88.0      0.0
# 515998                    389    True    ...        8.0    64.0      0.0
# 516946                   3106    True    ...       17.0   408.0    425.0
# 532494                   2573    True    ...       18.0   396.0    216.0
# 577695                   2350    True    ...       28.0  2436.0    952.0
# ...                       ...     ...    ...        ...     ...      ...
# 314302069                3237    True    ...       12.0   144.0      0.0
# 314771762                  69    True    ...       17.0   289.0      0.0
# 314971310                 309    True    ...        8.0    64.0      0.0
# 315015055                3582    True    ...        8.0    64.0      0.0
# 315240505                3052    True    ...        4.0    16.0      0.0
# 315584598                 777    True    ...       16.0   256.0      0.0
# 315684420                 153    True    ...        4.0    16.0      0.0
# 315714232                 442    True    ...       31.0  1023.0     62.0
# 315920586                 999    True    ...       92.0  8464.0      0.0
# 316213865                 449    True    ...        9.0    81.0      0.0
# 317304138                 355    True    ...        9.0    81.0      0.0
# merged_300 — слитые по каждому автору посты авторов, написавших от 50 до 300 слов включительно за рассчётный период.

# %% [markdown]
# Для авторов, у которых более 300 слов:
# Берём каждого пользователя. Последовательно сливаем его тексты и проверям количество слов. Если в какой-то момент это количество достигло или превысило 300, формируем документ. Затем формируем следующий документ.
# Если при такой нарезке последний кусок оказыается менее 50 слов, его к предыдущему.

# %%
groupedby_author_sum = data_authors_50.groupby("author_id").agg({"text_length": "sum"})
authors_more_300 = groupedby_author_sum[groupedby_author_sum["text_length"] > 300].index.values
data_authors_more_300 = data_authors_50[data_authors_50["author_id"].isin(authors_more_300)]
data_authors_more_300.shape
# Out:
# (3751675, 22)

# %% [markdown]
# Удаляем пользователей с id = 0.

# %%
data_authors_more_300 = data_authors_more_300[data_authors_more_300["author_id"] != 0]
data_authors_more_300.shape
# Out:
# (3558131, 22)

# %%
from collections import defaultdict

# result = {author_id: {docs: [("text", likes), ...], probs: [(t_num, prob)...], region: "str", age: "str", sex: int}, ...}

merged_more_300 = {}
for author_id, author_data in data_authors_more_300.groupby("author_id"):
    texts_storage = ""
    texts_number = len(author_data["text"])
    
    auth_dict = {}
    auth_dict["docs"] = []
    auth_dict["region"] = author_data["region"].iloc[0]
    
    
    for text_num, text in enumerate(author_data["text"]):
        last = (text_num + 1) == texts_number
        texts_storage += text
        
        if last:
            if len(texts_storage.split()) >= 50:
                # если это последний документ и количество слов в нём превышает 50 — формируем документ и формируем автора
                auth_dict["docs"].append(texts_storage)
                merged_more_300[author_id] = auth_dict
                texts_storage = "" 
            else:
                # а если не превышает — добавляем к предыдущему и формируем автора
                auth_dict["docs"][-1] += texts_storage
                merged_more_300[author_id] = auth_dict
                texts_storage = "" 
        else:
            if len(texts_storage.split()) >= 300:
                # если количество слов в документе достигло 300 — формируем документ
                auth_dict["docs"].append(texts_storage)
                texts_storage = ""
            else:
                # если ни одно условие не выполнено, продолжаем сливать
                continue

# %%
merged_300.rename(columns={"text": "docs"}, inplace=True)
merged_300_dict = merged_300.to_dict(orient="index")

# %%
len(merged_300_dict)

# %%
general_dict = {**merged_more_300, **merged_300_dict}
len(general_dict)

# %%
with open("/Users/Hun/hse_thesis/merged_texts_with_all_meta.pickle", "wb") as f:
    pickle.dump(general_dict, f)

# %%
texts = []
for auth_id, val in general_dict.items():
    for text in val["docs"]:
        texts.append(text)

# %%
dictionary = corpora.Dictionary([text.split() for text in texts])

# %%
dictionary.save("/Users/Hun/hse_thesis/hse_thesis.dict_v3")

# %%
corpus = [dictionary.doc2bow(text.split()) for text in texts]
corpora.MmCorpus.serialize("/Users/Hun/hse_thesis/hse_thesis.corpus_v3", corpus, metadata=True)

# %%
lda150 = models.LdaModel(corpus=corpus, id2word=dictionary, num_topics=150)

# %%
lda150.save("/Users/Hun/hse_thesis/lda150/hse_thesis_model150_v3.gen_mod")

# %%
lda150.print_topics(num_topics=-1, num_words=10)

# %%
lda150.minimum_probability = 0

# %%
for user_id, val in general_dict.items():
    general_dict[user_id]["probs"] = []
    for doc in val["docs"]:
        probs = lda150[dictionary.doc2bow(doc.split())]
        general_dict[user_id]["probs"].append([(t_num, prob) for t_num, prob in probs])
